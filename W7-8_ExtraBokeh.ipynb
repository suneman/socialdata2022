# %%
import pandas as pd

from bokeh.plotting import figure
from bokeh.io import show, output_notebook, reset_output
from bokeh.models import  ColumnDataSource, Legend

#reset_output() # If you are having issues with visualizing Bokeh plots in the notebook try to uncomment this line
output_notebook() # This is to make sure that bokeh plots in the notebook
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# **OVERVIEW** Here, below you have the backbone of the code I used to:
# 1. Load and preprocess the data
# 2. Create the data for the first plot in the interactive visualization
# 3. Create the first plot for the interactive visualiation with Bokeh
#
# **INSTRUCTIONS** I think you should try to have it done by yourself, because I personally find it harder to fill in someone elses code. However, some of you struggled to understand the instructions I gave during Week 7, so here you can see the "complete" draft of the code. Here, what you have to do:
# 1. Complete the three parts of the notebook to get the first plot of the Bokeh visualization done;
# 2. The first step is just the data preprocessing from Week 6 Ex. 3.2, the other two steps are those from Week8 Visualization 1.
# 3. Replace any `ADD_SOMETHING_SOMETHING` with the code.
#    * Each `ADD_SOMETHING_SOMETHING` gives you a hint of what to do. Read it carefully! For instance if I write `ADD_COLUMN_NAME` you should add the name of a column not the values of the column.
#    * Some are specific, some others are more general, e.g., `ADD_CODE`, because these are related to the new exercises you should solve.

# %% [markdown]
# > *Visualization 1.* Exploratory data analysis. The interactive visualization we are going to make uses the same code you put together for Week 7 Exercise 1.1 (where we made bar plot of the number of recommited crimes across ages divided by race), with a few changes/adds on:

# %% [markdown]
# Load and preprocess the data

# %%
#### Load the data ####
df = pd.read_csv("https://raw.githubusercontent.com/suneman/socialdata2022/main/files/recidivism_dataset_sub.csv")

#### Preprocess the data as in Week 6 Ex. 3.2 ####

#1) filter 
df = df[ADD_ALL_YOUR_FILTERS_HERE].reset_index().drop('index',axis=1)

#2) drop columns
df = df.drop([ADD_COLUMN_NAMES],axis=1) 

#### Create age_group column from column age ####
df['age_group'] = ADD_CODE

# %% [markdown]
# >    * First, instead of age, create an `age_group` column to use on the x-axis. The groups should be $(0,20],(20,40],(40,60],(60,80],(80,100]$.
# >    * Second, instead of using the number of recommitted crimes for each race, compute the total number of samples per age group and the total number of recommitted crimes per age group.

# %% [markdown]
# Prepare the data for the visualization: age group, number of recommitted crimes, number of total samples, and the two fractions for HoverTool (so you have them for later)

# %%
#Compute number of recommitted crimes and total number of samples
df_ = df.groupby(ADD_COLUMN_NAME).agg({ADD_COLUMN_TO_AGG:[ADD_FUNCTION_NAME_TO_GET_REC_CRIMES,
                                                          ADD_FUNCTION_NAME_TO_GET_TOTAL_SAMPLES]}).reset_index()

#fix the column names by following https://stackoverflow.com/questions/14189695/reset-a-columns-multiindex-levels
ADD_CODE_HERE

#Compute fraction of recommitted in group and across groups
df_['frac_recid'] = df_[ADD_N_REC_CRIMES_COLUMN_NAME]/df_[ADD_TOT_SAMPLES_COLUMN_NAME]
df_['frac_tot'] = df_[ADD_N_REC_CRIMES_COLUMN_NAME]/ADD_TOT_N_REC_CRIMES

# %% [markdown]
# Create the first figure in Bokeh for the Interactive Visualization.

# %%
#Convert your DataFrame to Bokeh ColumnDataSource
src = ColumnDataSource(ADD_DATAFRAME)

#Create an empty figure
p = figure(plot_width = ADD_WIDTH, plot_height = ADD_HEIGHT, title = ADD_TITLE,
           x_axis_label = ADD_XLABEL, y_axis_label = ADD_YLABEL, ADD_OTHER_PARAMS) 

#Define the columns to use for each bar
bar_cols = [ADD_COLUMN_NAME_TOT_SAMPLES, ADD_COLUMN_NAME_REC_CRIMES]

#Add bars by using p.var
bar ={} 
for indx,i in enumerate(bar_cols):
    bar[i] = p.vbar(x=ADD_COLUMN_NAME,  top=i, source= ADD_COLUMNDATASOURCE, width=ADD_WIDTH, 
                    legend_label=ADD_LABEL_FOR_LEGEND[i], color=ADD_COLORS[indx], muted = ADD_TRUE_OR_FALSE)
    
show(ADD_BOKEH_FIGURE)

# %% [markdown]
# This plot is ok, but we have to fix the legend. Below there are some lines of code that you have to add in the cell above. Figure out where to add each line.

# %%
#Create empty list for custom legend
items = []

#Append items to create the legend
items.append((ADD_LABEL_FOR_LEGEND[i], [bar[i]]))

#This is to manage the legend in plot
p.legend.visible = ADD_TRUE_OR_FALSE

#add the legend outside the plot
legend = Legend(items=ADD_ITEMS, location=ADD_LOCATION)
p.add_layout(ADD_THE_LEGEND, ADD_WHERE)
p.legend.click_policy = "mute" #you can also try "hide"

# %% [markdown]
# Now that you have the code for one plot you can continue with the exercise by:
# 1. adding `HoverTool` to show the fracions when hovering over the bars
# 2. recreating the same plot for `sex` and `race`
# 3. combining the three plots into one unique visualization with `Tabs` and `Panel`.
